# %%
from pathlib import Path
import xml.etree.ElementTree as ET
import random
import os
import shutil

PROJECT_ROOT = Path("..").resolve()
IMAGES_DIR = PROJECT_ROOT / "data" / "pre-procest"
ANN_DIR = PROJECT_ROOT / "data" / "annotations" 

TFRECORD_DIR = PROJECT_ROOT / "data" / "tfrecords"
MODELS_DIR = PROJECT_ROOT / "models"
CONFIGS_DIR = PROJECT_ROOT / "configs"
LABELMAP_PATH = CONFIGS_DIR / "label_map.pbtxt"

TFRECORD_DIR.mkdir(parents=True, exist_ok=True)
MODELS_DIR.mkdir(parents=True, exist_ok=True)
CONFIGS_DIR.mkdir(parents=True, exist_ok=True)

print(IMAGES_DIR)
print(ANN_DIR)
# Out:
# /home/wiebe/Desktop/data/pre-procest
# /home/wiebe/Desktop/data/annotations
